# %%
import pandas as pd
from IPython.display import clear_output

# %%
xls = pd.ExcelFile('hunt2.xlsx')
days = len(xls.sheet_names)
xls.sheet_names
# Out:
# ['29', '30', '01', '02', '03', '04', '05']

# %%
df1 = pd.read_excel(xls, '29')
df2 = pd.read_excel(xls, '30')
df3 = pd.read_excel(xls, '01')
df4 = pd.read_excel(xls, '02')
df5 = pd.read_excel(xls, '03')
df6 = pd.read_excel(xls, '04')
df7 = pd.read_excel(xls, '05')

frame = [df1, df2, df3, df4, df5, df6, df7]
Hunt = pd.concat(frame)
Hunt = Hunt.reset_index(drop=True)
Hunt = Hunt.rename(columns=lambda x:x.replace(' ', '_'))

# %%
class Guild():
    roster = []
    def __init__(self, name, total, hunt, purchased, one, two, three, four, five):
        self.name = name
        self.total = total
        self.hunt = hunt
        self.purchased = purchased
        self.one = one
        self.two = two
        self.three = three
        self.four = four
        self.five = five
        self.score = self.get_score()
        self.roster.append(self)
        
    def __repr__(self):
        return self.name       
    
    def get_score(self):
        return ((self.purchased * .3) + (self.two * .2) + (self.three * .5) + self.four + self.five)

# %%
# Initalize player instances
def get_roster():
    roster = []
    for _ in Hunt.Name:
        if _ not in roster:
            roster.append(_)
    for _ in roster:
        total = Hunt.query(f'Name == "{_}"').Total.sum()
        hunt = Hunt.query(f'Name == "{_}"').Hunt.sum()
        purchased = Hunt.query(f'Name == "{_}"').Purchase.sum()
        one = Hunt.query(f'Name == "{_}"').Level_1.sum()
        two = Hunt.query(f'Name == "{_}"').Level_2.sum()
        three = Hunt.query(f'Name == "{_}"').Level_3.sum()
        four = Hunt.query(f'Name == "{_}"').Level_4.sum()
        five = Hunt.query(f'Name == "{_}"').Level_5.sum()
        g = Guild(name=_, total=total, hunt=hunt, purchased=purchased, one=one, two=two, three=three, four=four, five=five)

# %%
# Finding the top Hunter
def top_hunter(roster):
    hunt = 0
    for _ in roster:
        if _.name != 'Total' and _.name != 'Anonymous' and _.hunt > hunt: hunt = _.hunt
    for _ in roster:
        if _.hunt == hunt:
            return _
        
# Find the top Buyer
def top_buyer(roster):
    purchases = 0
    for _ in roster:
        if _.name != 'Total' and _.name != 'Anonymous' and _.purchased > purchases: purchases = _.purchased
    for _ in roster:
        if _.purchased == purchases:
            return _
        
# Find the top Gifter
def top_gifter(roster):
    gifts = 0
    for _ in roster:
        if _.name != 'Total' and _.name != 'Anonymous' and _.total > gifts: gifts = _.total
    for _ in roster:
        if _.total == gifts: 
            return _
        
def top_points(roster):
    points = 0
    for _ in roster:
        if _.name != 'Total' and _.name != 'Anonymous' and _.score > points: points = _.score
    for _ in roster:
        if _.score == points:
            return _

# %%
# Breakdowns for categories
def breakdown(_, message):
    print(f"""{message} breakdown
    {message}: {_}
    Total Gifts: {_.total}
    Hunts: {_.hunt}
    Purchases: {_.purchased}
    Level 1s: {_.one}
    Level 2s: {_.two}
    Level 3s: {_.three}
    Level 4s: {_.four}
    Level 5s: {_.five}
    Total Points: {round(_.score, 2)}""")

# overall Breakdowns
def overall_breakdown(_):
    print(f"""{_} breakdown
    Total Gifts: {_.total}
    Hunts: {_.hunt}
    Purchases: {_.purchased}
    Level 1s: {_.one}
    Level 2s: {_.two}
    Level 3s: {_.three}
    Level 4s: {_.four}
    Level 5s: {_.five}
    Total Points: {round(_.score, 2)}""")


def session_average(_):
    print(f"""{days} day report average breakdown
    Total Gifts: {round(_.total/days, 2)}
    Hunts: {round(_.hunt/days, 2)}
    Purchases: {round(_.purchased/days, 2)}
    Level 1s: {round(_.one/days, 2)}
    Level 2s: {round(_.two/days, 2)}
    Level 3s: {round(_.three/days, 2)}
    Level 4s: {round(_.four/days, 2)}
    Level 5s: {round(_.five/days, 2)}
    Total Points: {round(_.score, 2)}""")

# %%
# Find a player
def find_player(player, roster):
    for _ in roster:
        if player == _.name:
            return _

# %%
# Finding the Naughty List
class Naughty(Guild):
    roster=[]
    
    @classmethod
    def get_naughty_list(self, days):
        print("""What it means to be on the naughty list:
    For each hunt report we recieve, we translate each level 2 hunted into .2 points, 
    level 3s into .5 points, and level 4/5 into 1 point each. 
    Purchasing a pack gives you .3 points. In total, each person is required to make 1 point daily.
    The number shown after your name is the number of total points you were missing for this hunt session.""")
        print()
        print(f"There are {len(self.roster)} players on the naughty list")
        for _ in self.roster:
            print(f"{_} is missing {round(days-_.score, 2)} days worth of completed hunts.")
        
def make_naughty_list(roster, days):
    for _ in roster:
        if _.score < days:
            Naughty(name=_.name, total=_.total, hunt=_.hunt, purchased=_.purchased, one=_.one, two=_.two, three=_.three, four=_.four, five=_.five)

# %%
def space_decorater():
    print()
    print("="*40)
    print()

# %%
def get_report():
    get_roster()
    make_naughty_list(Guild.roster, days)
    breakdown(top_hunter(Guild.roster), "Top Hunter")
    space_decorater()
    breakdown(top_buyer(Guild.roster), "Top Buyer")
    space_decorater()
    breakdown(top_gifter(Guild.roster), "Top Gifter")
    space_decorater()
    breakdown(top_points(Guild.roster), "Top Score")
    space_decorater()
    overall_breakdown(find_player("Total", Guild.roster))
    space_decorater()
    overall_breakdown(find_player("Anonymous", Guild.roster))
    space_decorater()
    session_average(find_player("Total", Guild.roster))
    space_decorater()
    Naughty.get_naughty_list(days)

# %%
get_report()
# Out:
# Top Hunter breakdown
#     Top Hunter: Executive LT
#     Total Gifts: 183
#     Hunts: 151
#     Purchases: 32
#     Level 1s: 0
#     Level 2s: 121
#     Level 3s: 19
#     Level 4s: 0
#     Level 5s: 11
#     Total Points: 54.3
#
# ========================================
#
# Top Buyer breakdown
#     Top Buyer: Highgarden
#     Total Gifts: 189
#     Hunts: 97
#     Purchases: 92
#     Level 1s: 0
#     Level 2s: 58
#     Level 3s: 32
#     Level 4s: 2
#     Level 5s: 5
#     Total Points: 62.2
#
# ========================================
#
# Top Gifter breakdown
#     Top Gifter: Highgarden
#     Total Gifts: 189
#     Hunts: 97
#     Purchases: 92
#     Level 1s: 0
#     Level 2s: 58
#     Level 3s: 32
#     Level 4s: 2
#     Level 5s: 5
#     Total Points: 62.2
#
# ========================================
#
# Top Score breakdown
#     Top Score: Highgarden
#     Total Gifts: 189
#     Hunts: 97
#     Purchases: 92
#     Level 1s: 0
#     Level 2s: 58
#     Level 3s: 32
#     Level 4s: 2
#     Level 5s: 5
#     Total Points: 62.2
#
# ========================================
#
# Total breakdown
#     Total Gifts: 3480
#     Hunts: 2303
#     Purchases: 1177
#     Level 1s: 0
#     Level 2s: 1461
#     Level 3s: 614
#     Level 4s: 120
#     Level 5s: 108
#     Total Points: 1180.3
#
# ========================================
#
# Anonymous breakdown
#     Total Gifts: 230
#     Hunts: 45
#     Purchases: 185
#     Level 1s: 0
#     Level 2s: 27
#     Level 3s: 9
#     Level 4s: 9
#     Level 5s: 0
#     Total Points: 74.4
#
# ========================================
#
# 7 day report average breakdown
#     Total Gifts: 497.14
#     Hunts: 329.0
#     Purchases: 168.14
#     Level 1s: 0.0
#     Level 2s: 208.71
#     Level 3s: 87.71
#     Level 4s: 17.14
#     Level 5s: 15.43
#     Total Points: 1180.3
#
# ========================================
#
# What it means to be on the naughty list:
#     For each hunt report we recieve, we translate each level 2 hunted into .2 points,
#     level 3s into .5 points, and level 4/5 into 1 point each.
#     Purchasing a pack gives you .3 points. In total, each person is required to make 1 point daily.
#     The number shown after your name is the number of total points you were missing for this hunt session.
#
# There are 63 players on the naughty list
# KloudStrife is missing 0.2 days worth of completed hunts.
# Aure87 is missing 5.6 days worth of completed hunts.
# CHSBank is missing 0.6 days worth of completed hunts.
# XoStewieXo is missing 6.6 days worth of completed hunts.
# Sir LickAlot is missing 0.2 days worth of completed hunts.
# Jeisonn1 is missing 0.8 days worth of completed hunts.
# XP AlboZ is missing 2.8 days worth of completed hunts.
# Bomonti is missing 5.2 days worth of completed hunts.
# L0RD KAN0N is missing 0.8 days worth of completed hunts.
# S L I M E is missing 1.0 days worth of completed hunts.
# ALVIROoOoS is missing 1.9 days worth of completed hunts.
# ShakeBurn is missing 1.1 days worth of completed hunts.
# Imafukyoface is missing 0.9 days worth of completed hunts.
# Sandokam is missing 2.1 days worth of completed hunts.
# Futt Bucker is missing 4.6 days worth of completed hunts.
# Trop 000 is missing 0.6 days worth of completed hunts.
# PEPSI  MAX is missing 5.3 days worth of completed hunts.
# alek sander is missing 1.5 days worth of completed hunts.
# Mr Hai GeGe is missing 0.5 days worth of completed hunts.
# XxWARRENxX is missing 0.9 days worth of completed hunts.
# KingJonSnow is missing 6.5 days worth of completed hunts.
# DEMPSEYROLL is missing 0.7 days worth of completed hunts.
# ozykel is missing 2.5 days worth of completed hunts.
# O SheWolf O is missing 4.9 days worth of completed hunts.
# xI Beast Ix is missing 5.9 days worth of completed hunts.
# Bloedrivier is missing 0.2 days worth of completed hunts.
# x TANJIRO xX is missing 3.5 days worth of completed hunts.
# Phat Sack is missing 6.6 days worth of completed hunts.
# Wendigo1 is missing 1.3 days worth of completed hunts.
# Figurehead is missing 4.0 days worth of completed hunts.
# Simicka111 is missing 3.4 days worth of completed hunts.
# ZzMCKzZ is missing 6.5 days worth of completed hunts.
# Luckylionblu is missing 6.1 days worth of completed hunts.
# WeakSauce1 is missing 3.0 days worth of completed hunts.
# TheSun90 is missing 2.0 days worth of completed hunts.
# MASAOkun is missing 4.2 days worth of completed hunts.
# CntRallyMe is missing 3.9 days worth of completed hunts.
# UNIQUE SOL is missing 0.4 days worth of completed hunts.
# n00b n4m3 is missing 6.5 days worth of completed hunts.
# BUZZER83 is missing 2.4 days worth of completed hunts.
# D1CKHEAD is missing 6.0 days worth of completed hunts.
# command01 is missing 6.1 days worth of completed hunts.
# xXxSavvYxXx is missing 5.5 days worth of completed hunts.
# PapaRangeR is missing 1.7 days worth of completed hunts.
# The Small is missing 4.7 days worth of completed hunts.
# MR savage 6 is missing 5.6 days worth of completed hunts.
# R0DRIGO is missing 4.5 days worth of completed hunts.
# 2 Phalops is missing 6.0 days worth of completed hunts.
# MaherVz is missing 6.5 days worth of completed hunts.
# Gonnnw is missing 1.3 days worth of completed hunts.
# Vk Sk123 is missing 4.9 days worth of completed hunts.
# Piesangbrood is missing 5.3 days worth of completed hunts.
# Eazy Clap is missing 0.9 days worth of completed hunts.
# CHIP B A B Y is missing 5.5 days worth of completed hunts.
# 1 Sweet 1 is missing 1.8 days worth of completed hunts.
# RSA Shane 1 is missing 6.0 days worth of completed hunts.
# fakyoutoo is missing 5.9 days worth of completed hunts.
# WizardPezz8 is missing 5.0 days worth of completed hunts.
# Call me Neo is missing 4.4 days worth of completed hunts.
# XP SuMi is missing 6.4 days worth of completed hunts.
# RAZ ALGUL is missing 6.5 days worth of completed hunts.
# xMACKx is missing 5.6 days worth of completed hunts.
# TankSA is missing 6.2 days worth of completed hunts.
